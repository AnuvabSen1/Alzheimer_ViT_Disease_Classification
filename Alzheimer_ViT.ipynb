# %% [markdown]
# <a href="https://colab.research.google.com/github/AnuvabSen1/Alzheimer_Disease/blob/main/Alzheimer_ViT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip 'ADNI.zip' -d '/content/Data/'
# !unzip '/content/drive/MyDrive/generated_augmented.zip' -d '/content/Data/'
# Out:
# Archive:  ADNI.zip
#    creating: /content/Data/ADNI/AD/
#   inflating: /content/Data/ADNI/AD/1.png
#   inflating: /content/Data/ADNI/AD/10.png
#   inflating: /content/Data/ADNI/AD/11.png
#   inflating: /content/Data/ADNI/AD/12.png
#   inflating: /content/Data/ADNI/AD/13.png
#   inflating: /content/Data/ADNI/AD/14.png
#   inflating: /content/Data/ADNI/AD/15.png
#   inflating: /content/Data/ADNI/AD/16.png
#   inflating: /content/Data/ADNI/AD/17.png
#   inflating: /content/Data/ADNI/AD/18.png
#   inflating: /content/Data/ADNI/AD/19.png
#   inflating: /content/Data/ADNI/AD/2.png
#   inflating: /content/Data/ADNI/AD/20.png
#   inflating: /content/Data/ADNI/AD/21.png
#   inflating: /content/Data/ADNI/AD/22.png
#   inflating: /content/Data/ADNI/AD/23.png
#   inflating: /content/Data/ADNI/AD/24.png
#   inflating: /content/Data/ADNI/AD/25.png
#   inflating: /content/Data/ADNI/AD/26.png
#   inflating: /content/Data/ADNI/AD/27.png
#   inflating: /content/Data/ADNI/AD/28.png
#   inflating: /content/Data/ADNI/AD/29.png
#   inflating: /content/Data/ADNI/AD/3.png
#   inflating: /content/Data/ADNI/AD/30.png
#   inflating: /content/Data/ADNI/AD/4.png
#   inflating: /content/Data/ADNI/AD/5.png
#   inflating: /content/Data/ADNI/AD/6.png
#   inflating: /content/Data/ADNI/AD/7.png
#   inflating: /content/Data/ADNI/AD/8.png
#   inflating: /content/Data/ADNI/AD/9.png
#    creating: /content/Data/ADNI/HC/
#   inflating: /content/Data/ADNI/HC/1.png
#   inflating: /content/Data/ADNI/HC/10.png
#   inflating: /content/Data/ADNI/HC/2.png
#   inflating: /content/Data/ADNI/HC/3.png
#   inflating: /content/Data/ADNI/HC/4.png
#   inflating: /content/Data/ADNI/HC/5.png
#   inflating: /content/Data/ADNI/HC/6.png
#   inflating: /content/Data/ADNI/HC/7.png
#   inflating: /content/Data/ADNI/HC/8.png
#   inflating: /content/Data/ADNI/HC/9.png
#   inflating: /content/Data/ADNI/HC/hemlo (1).png
#   inflating: /content/Data/ADNI/HC/hemlo (10).png
#   inflating: /content/Data/ADNI/HC/hemlo (2).png
#   inflating: /content/Data/ADNI/HC/hemlo (3).png
#   inflating: /content/Data/ADNI/HC/hemlo (4).png
#   inflating: /content/Data/ADNI/HC/hemlo (5).png
#   inflating: /content/Data/ADNI/HC/hemlo (6).png
#   inflating: /content/Data/ADNI/HC/hemlo (7).png
#   inflating: /content/Data/ADNI/HC/hemlo (8).png
#   inflating: /content/Data/ADNI/HC/hemlo (9).png
#   inflating: /content/Data/ADNI/HC/rename (1).png
#   inflating: /content/Data/ADNI/HC/rename (10).png
#   inflating: /content/Data/ADNI/HC/rename (2).png
#   inflating: /content/Data/ADNI/HC/rename (3).png
#   inflating: /content/Data/ADNI/HC/rename (4).png
#   inflating: /content/Data/ADNI/HC/rename (5).png
#   inflating: /content/Data/ADNI/HC/rename (6).png
#   inflating: /content/Data/ADNI/HC/rename (7).png
#   inflating: /content/Data/ADNI/HC/rename (8).png
#   inflating: /content/Data/ADNI/HC/rename (9).png
#    creating: /content/Data/ADNI/MCI/
#   inflating: /content/Data/ADNI/MCI/1.png
#   inflating: /content/Data/ADNI/MCI/10.png
#   inflating: /content/Data/ADNI/MCI/2.png
#   inflating: /content/Data/ADNI/MCI/3.png
#   inflating: /content/Data/ADNI/MCI/4.png
#   inflating: /content/Data/ADNI/MCI/5.png
#   inflating: /content/Data/ADNI/MCI/6.png
#   inflating: /content/Data/ADNI/MCI/7.png
#   inflating: /content/Data/ADNI/MCI/8.png
#   inflating: /content/Data/ADNI/MCI/9.png
#   inflating: /content/Data/ADNI/MCI/anuvab (1).png
#   inflating: /content/Data/ADNI/MCI/anuvab (10).png
#   inflating: /content/Data/ADNI/MCI/anuvab (2).png
#   inflating: /content/Data/ADNI/MCI/anuvab (3).png
#   inflating: /content/Data/ADNI/MCI/anuvab (4).png
#   inflating: /content/Data/ADNI/MCI/anuvab (5).png
#   inflating: /content/Data/ADNI/MCI/anuvab (6).png
#   inflating: /content/Data/ADNI/MCI/anuvab (7).png
#   inflating: /content/Data/ADNI/MCI/anuvab (8).png
#   inflating: /content/Data/ADNI/MCI/anuvab (9).png
#   inflating: /content/Data/ADNI/MCI/sad (1).png
#   inflating: /content/Data/ADNI/MCI/sad (10).png
#   inflating: /content/Data/ADNI/MCI/sad (2).png
#   inflating: /content/Data/ADNI/MCI/sad (3).png
#   inflating: /content/Data/ADNI/MCI/sad (4).png
#   inflating: /content/Data/ADNI/MCI/sad (5).png
#   inflating: /content/Data/ADNI/MCI/sad (6).png
#   inflating: /content/Data/ADNI/MCI/sad (7).png
#   inflating: /content/Data/ADNI/MCI/sad (8).png
#   inflating: /content/Data/ADNI/MCI/sad (9).png

# %%
# !mkdir '/content/Data/checkpoint'

# %%
import cv2
import matplotlib.pyplot as plt
import glob
import tqdm
from itertools import repeat

PATH = '/content/Data/'
ORIG_PATH = '/content/Data/ADNI/'
# GEN_PATH = '/content/Data/generated_augmented/'

# %%
import glob
import cv2
import numpy as np
import tqdm
from sklearn.model_selection import train_test_split

# Define the target image size (e.g., 224x224 for ViT-B/32)
target_image_size = (224, 224)

# Initialize empty lists for data and labels
y = []
z = []

# Load images and labels from subdirectories within ORIG_PATH
for subdirectory in ['AD', 'HC', 'MCI']:  # List of subdirectory names
    subdirectory_path = ORIG_PATH + subdirectory + '/'
    image_files = glob.glob(subdirectory_path + '*')

    if not image_files:
        print(f"No images found in {subdirectory_path}")
        continue

    for img in tqdm.tqdm(image_files, desc=f'Loading {subdirectory}'):
        img_data = cv2.imread(img)
        if img_data is not None:
            # Resize the image to the target size
            img_data = cv2.resize(img_data, target_image_size)
            z.append(img_data)
            y.append(subdirectory)  # Use the subdirectory name as the label

# Split data into training and testing sets (e.g., 80% training, 20% testing)
x_train, x_test, y_train, y_test = train_test_split(z, y, test_size=0.2, random_state=42)

# Print shapes of the training and testing sets
print("Train", np.array(x_train).shape)
print("Train", np.array(y_train).shape)
np.save(PATH + 'x_train.npy', np.array(x_train))
np.save(PATH + 'y_train.npy', np.array(y_train))

print("Test", np.array(x_test).shape)
print("Test", np.array(y_test).shape)
np.save(PATH + 'x_test.npy', np.array(x_test))
np.save(PATH + 'y_test.npy', np.array(y_test))
# Out:
# Loading AD: 100%|██████████| 30/30 [00:00<00:00, 225.17it/s]
# Loading HC: 100%|██████████| 30/30 [00:00<00:00, 407.15it/s]
# Loading MCI: 100%|██████████| 30/30 [00:00<00:00, 458.75it/s]
# Train (72, 224, 224, 3)
# Train (72,)
# Test (18, 224, 224, 3)
# Test (18,)

# %% [markdown]
# **PREPROCESSING**

# %% [markdown]
# **VIT TRAINING**

# %%
# !pip install tensorflow-addons
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (612 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.1/612.1 kB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.1)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.21.0 typeguard-2.13.3

# %% [markdown]
# **VIT TRAINED ON ORIGINAL DATASET**

# %%
from PIL import Image

# Load an example image
image = Image.open("/content/Data/ADNI/AD/5.png")  # Replace "example.jpg" with your image file path

# Get image dimensions
width, height = image.size
channels = 3  # Assuming it's an RGB image

# Set the input shape
input_shape = (height, width, channels)
print("Input shape:", input_shape)
# Out:
# Input shape: (256, 170, 3)

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

num_classes = 3
input_shape = (224, 224, 3)

x_train,y_train = np.load(PATH+'x_train.npy'), np.load(PATH+'y_train.npy')
label_encoder = preprocessing.LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
print(x_train.shape,y_train.shape)

x_test,y_test = np.load(PATH+'x_test.npy'), np.load(PATH+'y_test.npy')
label_encoder = preprocessing.LabelEncoder()
y_test = label_encoder.fit_transform(y_test)
print(x_test.shape,y_test.shape)

X = np.concatenate((x_train,x_test),axis=0)
y = np.concatenate((y_train,y_test),axis=0)
x_train, x_test, y_train, y_test = train_test_split(X,y,test_size=0.1)

print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")

learning_rate = 0.001
weight_decay = 0.0001
batch_size = 256
num_epochs = 100
image_size = 72  # We'll resize input images to this size
patch_size = 6   # Size of the patches to be extract from the input images
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 4
transformer_units = [
    projection_dim * 2,
    projection_dim,
]  # Size of the transformer layers
transformer_layers = 8
mlp_head_units = [2048, 1024]  # Size of the dense layers of the final classifier

data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(x_train)

def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

class Patches(layers.Layer):
    def __init__(self, patch_size):
        super().__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

import matplotlib.pyplot as plt

plt.figure(figsize=(4, 4))
image = x_train[np.random.choice(range(x_train.shape[0]))]
plt.imshow(image.astype("uint8"))
plt.axis("off")

resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(image_size, image_size)
)
patches = Patches(patch_size)(resized_image)
print(f"Image size: {image_size} X {image_size}")
print(f"Patch size: {patch_size} X {patch_size}")
print(f"Patches per image: {patches.shape[1]}")
print(f"Elements per patch: {patches.shape[-1]}")

n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(4, 4))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(patch_img.numpy().astype("uint8"))
    plt.axis("off")

class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super().__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

def create_vit_classifier():
    inputs = layers.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(num_classes)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    checkpoint_filepath = PATH+"/checkpoint/checkpoint"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    earlyStoppingCallback = keras.callbacks.EarlyStopping(patience=120, monitor='val_accuracy', restore_best_weights=True)

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.1,
        callbacks=[checkpoint_callback, earlyStoppingCallback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy, top_5_accuracy = model.evaluate(x_test, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return history


vit_classifier = create_vit_classifier()
history = run_experiment(vit_classifier)
# Out:
# (72, 224, 224, 3) (72,)
# (18, 224, 224, 3) (18,)
# x_train shape: (81, 224, 224, 3) - y_train shape: (81,)
# x_test shape: (9, 224, 224, 3) - y_test shape: (9,)
# Image size: 72 X 72
# Patch size: 6 X 6
# Patches per image: 144
# Elements per patch: 108
# Epoch 1/100
# 1/1 [==============================] - 18s 18s/step - loss: 2.7900 - accuracy: 0.3194 - top-5-accuracy: 1.0000 - val_loss: 20.7151 - val_accuracy: 0.3333 - val_top-5-accuracy: 1.0000
# Epoch 2/100
# 1/1 [==============================] - 1s 1s/step - loss: 19.0445 - accuracy: 0.3472 - top-5-accuracy: 1.0000 - val_loss: 8.6062 - val_accuracy: 0.4444 - val_top-5-accuracy: 1.0000
# Epoch 3/100
# 1/1 [==============================] - 0s 196ms/step - loss: 8.1402 - accuracy: 0.4028 - top-5-accuracy: 1.0000 - val_loss: 5.3486 - val_accuracy: 0.4444 - val_top-5-accuracy: 1.0000
# Epoch 4/100
# 1/1 [==============================] - 0s 183ms/step - loss: 5.0039 - accuracy: 0.3750 - top-5-accuracy: 1.0000 - val_loss: 5.3537 - val_accuracy: 0.4444 - val_top-5-accuracy: 1.0000
# Epoch 5/100
# 1/1 [==============================] - 0s 181ms/step - loss: 3.7195 - accuracy: 0.4861 - top-5-accuracy: 1.0000 - val_loss: 4.1038 - val_accuracy: 0.3333 - val_top-5-accuracy: 1.0000
# Epoch 6/100
# 1/1 [==============================] - 1s 1s/step - loss: 3.3269 - accuracy: 0.5417 - top-5-accuracy: 1.0000 - val_loss: 2.4246 - val_accuracy: 0.5556 - val_top-5-accuracy: 1.0000
# Epoch 7/100
# 1/1 [==============================] - 0s 175ms/step - loss: 3.9591 - accuracy: 0.4028 - top-5-accuracy: 1.0000 - val_loss: 2.1713 - val_accuracy: 0.4444 - val_top-5-accuracy: 1.0000
# Epoch 8/100
# 1/1 [==============================] - 0s 182ms/step - loss: 3.5674 - accuracy: 0.3611 - top-5-accuracy: 1.0000 - val_loss: 4.5515 - val_accuracy: 0.3333 - val_top-5-accuracy: 1.0000
# Epoch 9/100
# 1/1 [==============================] - 0s 172ms/step - loss: 2.6960 - accuracy: 0.4444 - top-5-accuracy: 1.0000 - val_loss: 5.0319 - val_accuracy: 0.2222 - val_top-5-accuracy: 1.0000
# Epoch 10/100
# 1/1 [==============================] - 0s 169ms/step - loss: 2.7281 - accuracy: 0.5694 - top-5-accuracy: 1.0000 - val_loss: 1.4141 - val_accuracy: 0.4444 - val_top-5-accuracy: 1.0000
# Epoch 11/100
# 1/1 [==============================] - 0s 170ms/step - loss: 1.9819 - accuracy: 0.5556 - top-5-accuracy: 1.0000 - val_loss: 0.8381 - val_accuracy: 0.4444 - val_top-5-accuracy: 1.0000
# Epoch 12/100
# 1/1 [==============================] - 4s 4s/step - loss: 2.0313 - accuracy: 0.5139 - top-5-accuracy: 1.0000 - val_loss: 0.6559 - val_accuracy: 0.6667 - val_top-5-accuracy: 1.0000
# Epoch 13/100
# 1/1 [==============================] - 0s 213ms/step - loss: 1.6047 - accuracy: 0.4861 - top-5-accuracy: 1.0000 - val_loss: 0.6519 - val_accuracy: 0.6667 - val_top-5-accuracy: 1.0000
# Epoch 14/100
# 1/1 [==============================] - 0s 173ms/step - loss: 0.8137 - accuracy: 0.7500 - top-5-accuracy: 1.0000 - val_loss: 1.0917 - val_accuracy: 0.6667 - val_top-5-accuracy: 1.0000
# Epoch 15/100
# 1/1 [==============================] - 0s 198ms/step - loss: 1.2636 - accuracy: 0.5694 - top-5-accuracy: 1.0000 - val_loss: 0.9008 - val_accuracy: 0.6667 - val_top-5-accuracy: 1.0000
# Epoch 16/100
# 1/1 [==============================] - 0s 246ms/step - loss: 1.3803 - accuracy: 0.6250 - top-5-accuracy: 1.0000 - val_loss: 1.1103 - val_accuracy: 0.4444 - val_top-5-accuracy: 1.0000
# Epoch 17/100
# 1/1 [==============================] - 0s 244ms/step - loss: 1.2635 - accuracy: 0.6111 - top-5-accuracy: 1.0000 - val_loss: 1.7237 - val_accuracy: 0.4444 - val_top-5-accuracy: 1.0000
# Epoch 18/100
# 1/1 [==============================] - 0s 220ms/step - loss: 1.2979 - accuracy: 0.5417 - top-5-accuracy: 1.0000 - val_loss: 1.2644 - val_accuracy: 0.4444 - val_top-5-accuracy: 1.0000
# Epoch 19/100
# 1/1 [==============================] - 0s 210ms/step - loss: 0.9829 - accuracy: 0.7361 - top-5-accuracy: 1.0000 - val_loss: 1.0400 - val_accuracy: 0.5556 - val_top-5-accuracy: 1.0000
# Epoch 20/100
# 1/1 [==============================] - 0s 251ms/step - loss: 0.9811 - accuracy: 0.6389 - top-5-accuracy: 1.0000 - val_loss: 0.7207 - val_accuracy: 0.6667 - val_top-5-accuracy: 1.0000
# Epoch 21/100
# 1/1 [==============================] - 2s 2s/step - loss: 1.1158 - accuracy: 0.6944 - top-5-accuracy: 1.0000 - val_loss: 0.5773 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 22/100
# 1/1 [==============================] - 0s 226ms/step - loss: 0.8919 - accuracy: 0.7361 - top-5-accuracy: 1.0000 - val_loss: 0.8095 - val_accuracy: 0.5556 - val_top-5-accuracy: 1.0000
# Epoch 23/100
# 1/1 [==============================] - 0s 250ms/step - loss: 0.6868 - accuracy: 0.7500 - top-5-accuracy: 1.0000 - val_loss: 1.0126 - val_accuracy: 0.5556 - val_top-5-accuracy: 1.0000
# Epoch 24/100
# 1/1 [==============================] - 0s 237ms/step - loss: 0.9589 - accuracy: 0.5972 - top-5-accuracy: 1.0000 - val_loss: 0.6709 - val_accuracy: 0.5556 - val_top-5-accuracy: 1.0000
# Epoch 25/100
# 1/1 [==============================] - 0s 196ms/step - loss: 0.8210 - accuracy: 0.6944 - top-5-accuracy: 1.0000 - val_loss: 0.6076 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 26/100
# 1/1 [==============================] - 0s 170ms/step - loss: 0.4525 - accuracy: 0.7778 - top-5-accuracy: 1.0000 - val_loss: 0.8472 - val_accuracy: 0.7778 - val_top-5-accuracy: 1.0000
# Epoch 27/100
# 1/1 [==============================] - 0s 165ms/step - loss: 0.8352 - accuracy: 0.7083 - top-5-accuracy: 1.0000 - val_loss: 1.1581 - val_accuracy: 0.7778 - val_top-5-accuracy: 1.0000
# Epoch 28/100
# 1/1 [==============================] - 0s 174ms/step - loss: 0.5004 - accuracy: 0.8472 - top-5-accuracy: 1.0000 - val_loss: 1.0300 - val_accuracy: 0.6667 - val_top-5-accuracy: 1.0000
# Epoch 29/100
# 1/1 [==============================] - 0s 168ms/step - loss: 0.5420 - accuracy: 0.7917 - top-5-accuracy: 1.0000 - val_loss: 0.7126 - val_accuracy: 0.6667 - val_top-5-accuracy: 1.0000
# Epoch 30/100
# 1/1 [==============================] - 0s 170ms/step - loss: 0.4843 - accuracy: 0.7639 - top-5-accuracy: 1.0000 - val_loss: 0.6005 - val_accuracy: 0.6667 - val_top-5-accuracy: 1.0000
# Epoch 31/100
# 1/1 [==============================] - 0s 175ms/step - loss: 0.5796 - accuracy: 0.7500 - top-5-accuracy: 1.0000 - val_loss: 0.4572 - val_accuracy: 0.7778 - val_top-5-accuracy: 1.0000
# Epoch 32/100
# 1/1 [==============================] - 0s 167ms/step - loss: 0.8507 - accuracy: 0.7222 - top-5-accuracy: 1.0000 - val_loss: 0.3371 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 33/100
# 1/1 [==============================] - 0s 177ms/step - loss: 0.1864 - accuracy: 0.9583 - top-5-accuracy: 1.0000 - val_loss: 0.4112 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 34/100
# 1/1 [==============================] - 0s 171ms/step - loss: 0.2485 - accuracy: 0.8750 - top-5-accuracy: 1.0000 - val_loss: 0.4989 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 35/100
# 1/1 [==============================] - 0s 172ms/step - loss: 0.5493 - accuracy: 0.8333 - top-5-accuracy: 1.0000 - val_loss: 0.6724 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 36/100
# 1/1 [==============================] - 0s 168ms/step - loss: 0.5268 - accuracy: 0.8056 - top-5-accuracy: 1.0000 - val_loss: 0.7191 - val_accuracy: 0.7778 - val_top-5-accuracy: 1.0000
# Epoch 37/100
# 1/1 [==============================] - 0s 178ms/step - loss: 0.4320 - accuracy: 0.8194 - top-5-accuracy: 1.0000 - val_loss: 0.6158 - val_accuracy: 0.7778 - val_top-5-accuracy: 1.0000
# Epoch 38/100
# 1/1 [==============================] - 0s 178ms/step - loss: 0.4103 - accuracy: 0.8333 - top-5-accuracy: 1.0000 - val_loss: 0.4509 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 39/100
# 1/1 [==============================] - 0s 168ms/step - loss: 0.3211 - accuracy: 0.8750 - top-5-accuracy: 1.0000 - val_loss: 0.3581 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 40/100
# 1/1 [==============================] - 0s 174ms/step - loss: 0.3442 - accuracy: 0.8611 - top-5-accuracy: 1.0000 - val_loss: 0.3667 - val_accuracy: 0.7778 - val_top-5-accuracy: 1.0000
# Epoch 41/100
# 1/1 [==============================] - 0s 183ms/step - loss: 0.3788 - accuracy: 0.8750 - top-5-accuracy: 1.0000 - val_loss: 0.3617 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 42/100
# 1/1 [==============================] - 0s 172ms/step - loss: 0.4126 - accuracy: 0.8333 - top-5-accuracy: 1.0000 - val_loss: 0.3283 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 43/100
# 1/1 [==============================] - 0s 167ms/step - loss: 0.4287 - accuracy: 0.8194 - top-5-accuracy: 1.0000 - val_loss: 0.4305 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 44/100
# 1/1 [==============================] - 0s 176ms/step - loss: 0.3452 - accuracy: 0.8611 - top-5-accuracy: 1.0000 - val_loss: 0.8072 - val_accuracy: 0.5556 - val_top-5-accuracy: 1.0000
# Epoch 45/100
# 1/1 [==============================] - 0s 172ms/step - loss: 0.3365 - accuracy: 0.8611 - top-5-accuracy: 1.0000 - val_loss: 0.8163 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 46/100
# 1/1 [==============================] - 0s 175ms/step - loss: 0.4345 - accuracy: 0.9028 - top-5-accuracy: 1.0000 - val_loss: 0.7401 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 47/100
# 1/1 [==============================] - 0s 169ms/step - loss: 0.1764 - accuracy: 0.9444 - top-5-accuracy: 1.0000 - val_loss: 0.7166 - val_accuracy: 0.7778 - val_top-5-accuracy: 1.0000
# Epoch 48/100
# 1/1 [==============================] - 0s 170ms/step - loss: 0.4799 - accuracy: 0.8194 - top-5-accuracy: 1.0000 - val_loss: 0.6139 - val_accuracy: 0.7778 - val_top-5-accuracy: 1.0000
# Epoch 49/100
# 1/1 [==============================] - 0s 170ms/step - loss: 0.2576 - accuracy: 0.9028 - top-5-accuracy: 1.0000 - val_loss: 0.5076 - val_accuracy: 0.7778 - val_top-5-accuracy: 1.0000
# Epoch 50/100
# 1/1 [==============================] - 0s 176ms/step - loss: 0.3278 - accuracy: 0.8750 - top-5-accuracy: 1.0000 - val_loss: 0.5131 - val_accuracy: 0.7778 - val_top-5-accuracy: 1.0000
# Epoch 51/100
# 1/1 [==============================] - 0s 171ms/step - loss: 0.1965 - accuracy: 0.9722 - top-5-accuracy: 1.0000 - val_loss: 0.5680 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 52/100
# 1/1 [==============================] - 0s 176ms/step - loss: 0.3411 - accuracy: 0.8750 - top-5-accuracy: 1.0000 - val_loss: 0.5589 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 53/100
# 1/1 [==============================] - 0s 175ms/step - loss: 0.1284 - accuracy: 0.9444 - top-5-accuracy: 1.0000 - val_loss: 0.5061 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 54/100
# 1/1 [==============================] - 0s 170ms/step - loss: 0.4216 - accuracy: 0.8611 - top-5-accuracy: 1.0000 - val_loss: 0.7094 - val_accuracy: 0.7778 - val_top-5-accuracy: 1.0000
# Epoch 55/100
# 1/1 [==============================] - 0s 184ms/step - loss: 0.3124 - accuracy: 0.9306 - top-5-accuracy: 1.0000 - val_loss: 0.8339 - val_accuracy: 0.7778 - val_top-5-accuracy: 1.0000
# Epoch 56/100
# 1/1 [==============================] - 0s 179ms/step - loss: 0.2219 - accuracy: 0.9444 - top-5-accuracy: 1.0000 - val_loss: 0.8666 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 57/100
# 1/1 [==============================] - 0s 177ms/step - loss: 0.2866 - accuracy: 0.8889 - top-5-accuracy: 1.0000 - val_loss: 0.6170 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 58/100
# 1/1 [==============================] - 0s 175ms/step - loss: 0.1296 - accuracy: 0.9444 - top-5-accuracy: 1.0000 - val_loss: 0.3878 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 59/100
# 1/1 [==============================] - 0s 180ms/step - loss: 0.0672 - accuracy: 1.0000 - top-5-accuracy: 1.0000 - val_loss: 0.2598 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 60/100
# 1/1 [==============================] - 0s 176ms/step - loss: 0.2152 - accuracy: 0.9444 - top-5-accuracy: 1.0000 - val_loss: 0.1902 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 61/100
# 1/1 [==============================] - 0s 181ms/step - loss: 0.2476 - accuracy: 0.9028 - top-5-accuracy: 1.0000 - val_loss: 0.2693 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 62/100
# 1/1 [==============================] - 0s 171ms/step - loss: 0.1979 - accuracy: 0.9306 - top-5-accuracy: 1.0000 - val_loss: 0.8104 - val_accuracy: 0.7778 - val_top-5-accuracy: 1.0000
# Epoch 63/100
# 1/1 [==============================] - 0s 175ms/step - loss: 0.2877 - accuracy: 0.8889 - top-5-accuracy: 1.0000 - val_loss: 1.3948 - val_accuracy: 0.6667 - val_top-5-accuracy: 1.0000
# Epoch 64/100
# 1/1 [==============================] - 0s 179ms/step - loss: 0.2374 - accuracy: 0.9167 - top-5-accuracy: 1.0000 - val_loss: 1.5144 - val_accuracy: 0.6667 - val_top-5-accuracy: 1.0000
# Epoch 65/100
# 1/1 [==============================] - 0s 170ms/step - loss: 0.1936 - accuracy: 0.9167 - top-5-accuracy: 1.0000 - val_loss: 1.0461 - val_accuracy: 0.7778 - val_top-5-accuracy: 1.0000
# Epoch 66/100
# 1/1 [==============================] - 0s 185ms/step - loss: 0.3204 - accuracy: 0.8889 - top-5-accuracy: 1.0000 - val_loss: 0.3852 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 67/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.1186 - accuracy: 0.9583 - top-5-accuracy: 1.0000 - val_loss: 0.1210 - val_accuracy: 1.0000 - val_top-5-accuracy: 1.0000
# Epoch 68/100
# 1/1 [==============================] - 0s 181ms/step - loss: 0.0887 - accuracy: 0.9583 - top-5-accuracy: 1.0000 - val_loss: 0.2326 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 69/100
# 1/1 [==============================] - 0s 179ms/step - loss: 0.4071 - accuracy: 0.8611 - top-5-accuracy: 1.0000 - val_loss: 0.1159 - val_accuracy: 1.0000 - val_top-5-accuracy: 1.0000
# Epoch 70/100
# 1/1 [==============================] - 0s 176ms/step - loss: 0.0421 - accuracy: 0.9861 - top-5-accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 71/100
# 1/1 [==============================] - 0s 174ms/step - loss: 0.1770 - accuracy: 0.9444 - top-5-accuracy: 1.0000 - val_loss: 0.5169 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 72/100
# 1/1 [==============================] - 0s 172ms/step - loss: 0.1376 - accuracy: 0.9583 - top-5-accuracy: 1.0000 - val_loss: 1.1623 - val_accuracy: 0.6667 - val_top-5-accuracy: 1.0000
# Epoch 73/100
# 1/1 [==============================] - 0s 178ms/step - loss: 0.2991 - accuracy: 0.9306 - top-5-accuracy: 1.0000 - val_loss: 1.3088 - val_accuracy: 0.6667 - val_top-5-accuracy: 1.0000
# Epoch 74/100
# 1/1 [==============================] - 0s 233ms/step - loss: 0.1525 - accuracy: 0.9306 - top-5-accuracy: 1.0000 - val_loss: 0.8525 - val_accuracy: 0.6667 - val_top-5-accuracy: 1.0000
# Epoch 75/100
# 1/1 [==============================] - 0s 242ms/step - loss: 0.2234 - accuracy: 0.9306 - top-5-accuracy: 1.0000 - val_loss: 0.4686 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 76/100
# 1/1 [==============================] - 0s 252ms/step - loss: 0.0598 - accuracy: 0.9722 - top-5-accuracy: 1.0000 - val_loss: 0.2916 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 77/100
# 1/1 [==============================] - 0s 218ms/step - loss: 0.0735 - accuracy: 0.9722 - top-5-accuracy: 1.0000 - val_loss: 0.2989 - val_accuracy: 0.7778 - val_top-5-accuracy: 1.0000
# Epoch 78/100
# 1/1 [==============================] - 0s 239ms/step - loss: 0.1905 - accuracy: 0.9167 - top-5-accuracy: 1.0000 - val_loss: 0.3523 - val_accuracy: 0.7778 - val_top-5-accuracy: 1.0000
# Epoch 79/100
# 1/1 [==============================] - 0s 247ms/step - loss: 0.1822 - accuracy: 0.9167 - top-5-accuracy: 1.0000 - val_loss: 0.3306 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 80/100
# 1/1 [==============================] - 0s 228ms/step - loss: 0.2099 - accuracy: 0.9167 - top-5-accuracy: 1.0000 - val_loss: 0.3238 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 81/100
# 1/1 [==============================] - 0s 208ms/step - loss: 0.0397 - accuracy: 0.9722 - top-5-accuracy: 1.0000 - val_loss: 0.4734 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 82/100
# 1/1 [==============================] - 0s 207ms/step - loss: 0.1286 - accuracy: 0.9722 - top-5-accuracy: 1.0000 - val_loss: 0.6761 - val_accuracy: 0.7778 - val_top-5-accuracy: 1.0000
# Epoch 83/100
# 1/1 [==============================] - 0s 211ms/step - loss: 0.1270 - accuracy: 0.9583 - top-5-accuracy: 1.0000 - val_loss: 0.7954 - val_accuracy: 0.6667 - val_top-5-accuracy: 1.0000
# Epoch 84/100
# 1/1 [==============================] - 0s 213ms/step - loss: 0.1263 - accuracy: 0.9306 - top-5-accuracy: 1.0000 - val_loss: 0.5863 - val_accuracy: 0.7778 - val_top-5-accuracy: 1.0000
# Epoch 85/100
# 1/1 [==============================] - 0s 238ms/step - loss: 0.2171 - accuracy: 0.9444 - top-5-accuracy: 1.0000 - val_loss: 0.2681 - val_accuracy: 0.7778 - val_top-5-accuracy: 1.0000
# Epoch 86/100
# 1/1 [==============================] - 0s 220ms/step - loss: 0.1168 - accuracy: 0.9583 - top-5-accuracy: 1.0000 - val_loss: 0.1411 - val_accuracy: 1.0000 - val_top-5-accuracy: 1.0000
# Epoch 87/100
# 1/1 [==============================] - 0s 218ms/step - loss: 0.1721 - accuracy: 0.9306 - top-5-accuracy: 1.0000 - val_loss: 0.1148 - val_accuracy: 1.0000 - val_top-5-accuracy: 1.0000
# Epoch 88/100
# 1/1 [==============================] - 0s 212ms/step - loss: 0.1097 - accuracy: 0.9444 - top-5-accuracy: 1.0000 - val_loss: 0.1287 - val_accuracy: 1.0000 - val_top-5-accuracy: 1.0000
# Epoch 89/100
# 1/1 [==============================] - 0s 239ms/step - loss: 0.1131 - accuracy: 0.9583 - top-5-accuracy: 1.0000 - val_loss: 0.1629 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 90/100
# 1/1 [==============================] - 0s 225ms/step - loss: 0.0775 - accuracy: 0.9722 - top-5-accuracy: 1.0000 - val_loss: 0.1614 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 91/100
# 1/1 [==============================] - 0s 180ms/step - loss: 0.0466 - accuracy: 0.9861 - top-5-accuracy: 1.0000 - val_loss: 0.1677 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 92/100
# 1/1 [==============================] - 0s 173ms/step - loss: 0.0213 - accuracy: 1.0000 - top-5-accuracy: 1.0000 - val_loss: 0.1707 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 93/100
# 1/1 [==============================] - 0s 172ms/step - loss: 0.1114 - accuracy: 0.9722 - top-5-accuracy: 1.0000 - val_loss: 0.1724 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 94/100
# 1/1 [==============================] - 0s 216ms/step - loss: 0.0772 - accuracy: 0.9861 - top-5-accuracy: 1.0000 - val_loss: 0.1766 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 95/100
# 1/1 [==============================] - 0s 179ms/step - loss: 0.1483 - accuracy: 0.9028 - top-5-accuracy: 1.0000 - val_loss: 0.2340 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 96/100
# 1/1 [==============================] - 0s 171ms/step - loss: 0.2812 - accuracy: 0.9444 - top-5-accuracy: 1.0000 - val_loss: 0.1837 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 97/100
# 1/1 [==============================] - 0s 180ms/step - loss: 0.1549 - accuracy: 0.9583 - top-5-accuracy: 1.0000 - val_loss: 0.1470 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 98/100
# 1/1 [==============================] - 0s 169ms/step - loss: 0.0784 - accuracy: 0.9722 - top-5-accuracy: 1.0000 - val_loss: 0.2176 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 99/100
# 1/1 [==============================] - 0s 175ms/step - loss: 0.1982 - accuracy: 0.9444 - top-5-accuracy: 1.0000 - val_loss: 0.2091 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# Epoch 100/100
# 1/1 [==============================] - 0s 166ms/step - loss: 0.0774 - accuracy: 0.9583 - top-5-accuracy: 1.0000 - val_loss: 0.2234 - val_accuracy: 0.8889 - val_top-5-accuracy: 1.0000
# 1/1 [==============================] - 0s 45ms/step - loss: 0.4055 - accuracy: 0.8889 - top-5-accuracy: 1.0000
# Test accuracy: 88.89%
# Test top 5 accuracy: 100.0%

# %%
import json
history_dict = history.history
json.dump(history_dict, open('/content/Data/checkpoint/history_generated', 'w'))

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score, RocCurveDisplay, auc
import seaborn as sns
y_predict = vit_classifier.predict(x_test)
y_pred = np.argmax(np.round(y_predict), axis=1)
sns.heatmap(confusion_matrix(y_test, y_pred))
print('\nClassification Report:\n', classification_report(y_test, y_pred))
confusion_matrix_graph = confusion_matrix(y_test, y_pred)
print(confusion_matrix_graph)
# Out:
# 1/1 [==============================] - 2s 2s/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      0.75      0.86         4
#            2       0.67      1.00      0.80         2
#
#     accuracy                           0.89         9
#    macro avg       0.89      0.92      0.89         9
# weighted avg       0.93      0.89      0.89         9
#
# [[3 0 0]
#  [0 3 1]
#  [0 0 2]]
